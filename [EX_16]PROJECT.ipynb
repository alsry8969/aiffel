# %% [markdown]
# # 16-13. 프로젝트 : Segmentation map으로 도로 이미지 만들기

# %% [markdown]
# 이전 Pix2Pix 논문에서 제시한 결과 중에 아래와 같은 실험 결과가 있었습니다. 도로의 레이블 정보를 활용해 이미지를 생성해낸 결과입니다.
#
# ![image.png](attachment:image.png)
#
# 이번 프로젝트는 위와 같은 데이터셋을 이용해 Pix2Pix를 학습시켜보는 것입니다. 데이터셋은 아래에서 다운로드할 수 있습니다.
# 1000개의 학습용 이미지 및 5개의 평가 이미지를 포함합니다.
#
# - cityscapes.zip
#     - https://d3s0tskafalll9.cloudfront.net/media/documents/cityscapes.zip
#
# 이전 포켓몬 데이터에서 사용했던 스케치와는 조금 다른 레이블 정보 이미지를 입력으로 사용하기 때문에, 전처리 과정에 대해 약간의 혼란이 있을 수 있지만 크게 다른 과정은 없습니다.
# 아래 Tensroflow에서 제공하는 Pix2Pix 튜토리얼은 위 이미지와 비슷한 레이블 정보 이미지를 사용하기 때문에 좋은 참고 자료가 될 수 있을 것 같습니다.
#
# 프로젝트 시작에 어려움이 있다면 아래 튜토리얼을 참고하시면서 이번 프로젝트를 수행해 봅시다.
# (아래 튜토리얼은 Pix2Pix 구조를 Functional API를 이용해 구현하기 때문에 이번에 진행한 Subclassing 방법을 이용한 모델 구현과 비교하면서 구현 방법에 대해서도 공부해 보시길 추천드립니다)
#
# - Tensorflow Pix2Pix Tutorial
#     - https://www.tensorflow.org/tutorials/generative/pix2pix?hl=ko

# %% [markdown]
# 프로젝트를 수행하기 전에 주요 라이브러리 버전을 살펴 봅시다.

# %%
import numpy
import tensorflow

print(numpy.__version__)
print(tensorflow.__version__)
# Out:
# 1.21.4
# 2.6.0

# %% [markdown]
# ### 프로젝트 수행
# 프로젝트를 진행하면서 필수로 수행해야 할 사항은 다음과 같습니다.
#
# 1. 데이터에 한 가지 이상의 augmentation 방법을 적용하여 학습해 주세요.(어떠한 방법을 사용했는지 적어주세요.)
# 2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용해 주세요.
# 3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운로드했던 "val" 폴더 내 이미지를 사용해 주세요.
# 4. 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화해 주세요.
# 5. 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 중간 손실 값에 대한 로그를 남겨주세요. 좋은 결과를 얻기 위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.

# %% [markdown]
# ### 1. augmentation 적용

# %%
# 이미지 개수 확인
import os

data_path = os.getenv('HOME')+'/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
# 이미지 확인하기
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 11):
    f = data_path + os.listdir(data_path)[np.random.randint(1000)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(5,2,i)
    plt.imshow(img)

# %%
# 이미지 크기 확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
# 이미지 나누기
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
# apply augmentation
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
# 시각화
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
# 시각화 - apply augmentation
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# ### 2. U-Net Generator

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
# 출력 시각화
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# ### 3. 모델 학습 후 테스트

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 100

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:1.0410
# L1_loss:0.3851
# Discriminator_loss:1.4315
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.2355
# L1_loss:0.2842
# Discriminator_loss:1.1707
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.2732
# L1_loss:0.2736
# Discriminator_loss:0.9239
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.1942
# L1_loss:0.2786
# Discriminator_loss:0.8897
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.7546
# L1_loss:0.2340
# Discriminator_loss:0.5574
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.7737
# L1_loss:0.2217
# Discriminator_loss:0.6322
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.3255
# L1_loss:0.2644
# Discriminator_loss:0.5986
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.7288
# L1_loss:0.2566
# Discriminator_loss:0.5983
#
# EPOCH[1] - STEP[90]
# Generator_loss:1.2357
# L1_loss:0.2557
# Discriminator_loss:0.8506
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.6944
# L1_loss:0.2271
# Discriminator_loss:1.0066
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.1653
# L1_loss:0.2419
# Discriminator_loss:1.1789
#
# EPOCH[1] - STEP[120]
# Generator_loss:2.1918
# L1_loss:0.2562
# Discriminator_loss:0.5594
#
# EPOCH[1] - STEP[130]
# Generator_loss:0.9847
# L1_loss:0.2521
# Discriminator_loss:0.9100
#
# EPOCH[1] - STEP[140]
# Generator_loss:2.2894
# L1_loss:0.2250
# Discriminator_loss:0.4088
#
# EPOCH[1] - STEP[150]
# Generator_loss:2.0923
# L1_loss:0.1957
# Discriminator_loss:0.5533
#
# EPOCH[1] - STEP[160]
# Generator_loss:2.6353
# L1_loss:0.2817
# Discriminator_loss:0.3109
#
# EPOCH[1] - STEP[170]
# Generator_loss:1.1779
# L1_loss:0.2432
# Discriminator_loss:0.8736
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.9852
# L1_loss:0.2065
# Discriminator_loss:0.5122
#
# EPOCH[1] - STEP[190]
# Generator_loss:2.1879
# L1_loss:0.2310
# Discriminator_loss:0.6550
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.9201
# L1_loss:0.2130
# Discriminator_loss:0.3761
#
# EPOCH[1] - STEP[210]
# Generator_loss:2.5857
# L1_loss:0.1992
# Discriminator_loss:0.6288
#
# EPOCH[1] - STEP[220]
# Generator_loss:2.7305
# L1_loss:0.2139
# Discriminator_loss:1.1308
#
# EPOCH[1] - STEP[230]
# Generator_loss:2.5262
# L1_loss:0.2185
# Discriminator_loss:0.6139
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.9749
# L1_loss:0.2353
# Discriminator_loss:0.6352
#
# EPOCH[1] - STEP[250]
# Generator_loss:2.1982
# L1_loss:0.2612
# Discriminator_loss:0.4054
#
# EPOCH[2] - STEP[10]
# Generator_loss:2.2433
# L1_loss:0.2070
# Discriminator_loss:0.4838
#
# EPOCH[2] - STEP[20]
# Generator_loss:1.2022
# L1_loss:0.2316
# Discriminator_loss:0.6248
#
# EPOCH[2] - STEP[30]
# Generator_loss:0.5829
# L1_loss:0.2316
# Discriminator_loss:1.1561
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.4651
# L1_loss:0.2795
# Discriminator_loss:0.4655
#
# EPOCH[2] - STEP[50]
# Generator_loss:2.5794
# L1_loss:0.2263
# Discriminator_loss:1.2816
#
# EPOCH[2] - STEP[60]
# Generator_loss:2.6304
# L1_loss:0.2329
# Discriminator_loss:0.2148
#
# EPOCH[2] - STEP[70]
# Generator_loss:3.0881
# L1_loss:0.1895
# Discriminator_loss:0.5320
#
# EPOCH[2] - STEP[80]
# Generator_loss:2.1154
# L1_loss:0.2020
# Discriminator_loss:0.7774
#
# EPOCH[2] - STEP[90]
# Generator_loss:1.1465
# L1_loss:0.2203
# Discriminator_loss:0.8311
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.0949
# L1_loss:0.2207
# Discriminator_loss:0.8808
#
# EPOCH[2] - STEP[110]
# Generator_loss:1.7040
# L1_loss:0.2157
# Discriminator_loss:0.4117
#
# EPOCH[2] - STEP[120]
# Generator_loss:1.0279
# L1_loss:0.1963
# Discriminator_loss:0.9930
#
# EPOCH[2] - STEP[130]
# Generator_loss:1.2979
# L1_loss:0.1927
# Discriminator_loss:0.5417
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.6327
# L1_loss:0.2607
# Discriminator_loss:0.4836
#
# EPOCH[2] - STEP[150]
# Generator_loss:2.1528
# L1_loss:0.2288
# Discriminator_loss:0.9800
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.6214
# L1_loss:0.2413
# Discriminator_loss:0.3423
#
# EPOCH[2] - STEP[170]
# Generator_loss:2.0159
# L1_loss:0.2062
# Discriminator_loss:0.3876
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.6920
# L1_loss:0.2132
# Discriminator_loss:1.4608
#
# EPOCH[2] - STEP[190]
# Generator_loss:1.1213
# L1_loss:0.1963
# Discriminator_loss:1.2488
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.3729
# L1_loss:0.1733
# Discriminator_loss:0.5190
#
# EPOCH[2] - STEP[210]
# Generator_loss:2.5723
# L1_loss:0.1673
# Discriminator_loss:0.9130
#
# EPOCH[2] - STEP[220]
# Generator_loss:2.3126
# L1_loss:0.1753
# Discriminator_loss:0.3478
#
# EPOCH[2] - STEP[230]
# Generator_loss:2.1973
# L1_loss:0.2250
# Discriminator_loss:0.3019
#
# EPOCH[2] - STEP[240]
# Generator_loss:3.1665
# L1_loss:0.1983
# Discriminator_loss:0.4570
#
# EPOCH[2] - STEP[250]
# Generator_loss:2.3479
# L1_loss:0.1902
# Discriminator_loss:0.9618
#
# EPOCH[3] - STEP[10]
# Generator_loss:2.4901
# L1_loss:0.1983
# Discriminator_loss:0.2992
#
# EPOCH[3] - STEP[20]
# Generator_loss:2.7350
# L1_loss:0.1916
# Discriminator_loss:0.4568
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.0357
# L1_loss:0.2562
# Discriminator_loss:0.6872
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.8773
# L1_loss:0.1985
# Discriminator_loss:0.4521
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.7822
# L1_loss:0.2319
# Discriminator_loss:0.3285
#
# EPOCH[3] - STEP[60]
# Generator_loss:2.3291
# L1_loss:0.1989
# Discriminator_loss:0.5822
#
# EPOCH[3] - STEP[70]
# Generator_loss:2.8274
# L1_loss:0.2246
# Discriminator_loss:0.2669
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.9137
# L1_loss:0.2214
# Discriminator_loss:0.3941
#
# EPOCH[3] - STEP[90]
# Generator_loss:1.0762
# L1_loss:0.2230
# Discriminator_loss:0.8586
#
# EPOCH[3] - STEP[100]
# Generator_loss:2.3282
# L1_loss:0.2053
# Discriminator_loss:0.4763
#
# EPOCH[3] - STEP[110]
# Generator_loss:3.4375
# L1_loss:0.2161
# Discriminator_loss:0.8936
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.7225
# L1_loss:0.2222
# Discriminator_loss:0.6004
#
# EPOCH[3] - STEP[130]
# Generator_loss:0.8150
# L1_loss:0.2253
# Discriminator_loss:0.7972
#
# EPOCH[3] - STEP[140]
# Generator_loss:2.9775
# L1_loss:0.2590
# Discriminator_loss:0.4100
#
# EPOCH[3] - STEP[150]
# Generator_loss:1.1578
# L1_loss:0.1570
# Discriminator_loss:1.0788
#
# EPOCH[3] - STEP[160]
# Generator_loss:2.9022
# L1_loss:0.1847
# Discriminator_loss:1.3160
#
# EPOCH[3] - STEP[170]
# Generator_loss:2.3032
# L1_loss:0.1926
# Discriminator_loss:0.4161
#
# EPOCH[3] - STEP[180]
# Generator_loss:1.4627
# L1_loss:0.1843
# Discriminator_loss:0.6539
#
# EPOCH[3] - STEP[190]
# Generator_loss:2.5881
# L1_loss:0.2103
# Discriminator_loss:0.6396
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.2196
# L1_loss:0.1855
# Discriminator_loss:0.5796
#
# EPOCH[3] - STEP[210]
# Generator_loss:1.7328
# L1_loss:0.1823
# Discriminator_loss:0.3517
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.2177
# L1_loss:0.1903
# Discriminator_loss:0.8121
#
# EPOCH[3] - STEP[230]
# Generator_loss:2.0922
# L1_loss:0.2101
# Discriminator_loss:0.6419
#
# EPOCH[3] - STEP[240]
# Generator_loss:1.1966
# L1_loss:0.2340
# Discriminator_loss:0.5443
#
# EPOCH[3] - STEP[250]
# Generator_loss:1.6931
# L1_loss:0.2117
# Discriminator_loss:0.5670
#
# EPOCH[4] - STEP[10]
# Generator_loss:0.5972
# L1_loss:0.1933
# Discriminator_loss:1.2493
#
# EPOCH[4] - STEP[20]
# Generator_loss:2.3759
# L1_loss:0.2258
# Discriminator_loss:2.8592
#
# EPOCH[4] - STEP[30]
# Generator_loss:2.6035
# L1_loss:0.1716
# Discriminator_loss:0.7277
#
# EPOCH[4] - STEP[40]
# Generator_loss:1.5550
# L1_loss:0.1783
# Discriminator_loss:0.6218
#
# EPOCH[4] - STEP[50]
# Generator_loss:1.8177
# L1_loss:0.1999
# Discriminator_loss:0.4192
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.0868
# L1_loss:0.1723
# Discriminator_loss:0.7163
#
# EPOCH[4] - STEP[70]
# Generator_loss:1.3877
# L1_loss:0.1848
# Discriminator_loss:0.5706
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.8728
# L1_loss:0.1879
# Discriminator_loss:0.7044
#
# EPOCH[4] - STEP[90]
# Generator_loss:1.2218
# L1_loss:0.2468
# Discriminator_loss:0.6726
#
# EPOCH[4] - STEP[100]
# Generator_loss:0.8827
# L1_loss:0.2168
# Discriminator_loss:0.8339
#
# EPOCH[4] - STEP[110]
# Generator_loss:2.4395
# L1_loss:0.2066
# Discriminator_loss:1.0383
#
# EPOCH[4] - STEP[120]
# Generator_loss:2.4402
# L1_loss:0.1985
# Discriminator_loss:0.8593
#
# EPOCH[4] - STEP[130]
# Generator_loss:0.9455
# L1_loss:0.2824
# Discriminator_loss:0.6510
#
# EPOCH[4] - STEP[140]
# Generator_loss:1.8106
# L1_loss:0.1770
# Discriminator_loss:0.3608
#
# EPOCH[4] - STEP[150]
# Generator_loss:0.6677
# L1_loss:0.1962
# Discriminator_loss:0.9978
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.5074
# L1_loss:0.1911
# Discriminator_loss:0.7387
#
# EPOCH[4] - STEP[170]
# Generator_loss:2.5813
# L1_loss:0.2141
# Discriminator_loss:0.4193
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.5647
# L1_loss:0.2053
# Discriminator_loss:0.8376
#
# EPOCH[4] - STEP[190]
# Generator_loss:1.0638
# L1_loss:0.1925
# Discriminator_loss:0.9957
#
# EPOCH[4] - STEP[200]
# Generator_loss:2.1002
# L1_loss:0.1927
# Discriminator_loss:0.4398
#
# EPOCH[4] - STEP[210]
# Generator_loss:1.8948
# L1_loss:0.2125
# Discriminator_loss:0.6220
#
# EPOCH[4] - STEP[220]
# Generator_loss:1.6810
# L1_loss:0.2529
# Discriminator_loss:0.9559
#
# EPOCH[4] - STEP[230]
# Generator_loss:0.5781
# L1_loss:0.2783
# Discriminator_loss:1.4952
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.5876
# L1_loss:0.1821
# Discriminator_loss:0.5880
#
# EPOCH[4] - STEP[250]
# Generator_loss:2.5945
# L1_loss:0.2268
# Discriminator_loss:0.5299
#
# EPOCH[5] - STEP[10]
# Generator_loss:2.4758
# L1_loss:0.2202
# Discriminator_loss:0.2484
#
# EPOCH[5] - STEP[20]
# Generator_loss:1.4235
# L1_loss:0.1832
# Discriminator_loss:0.7552
#
# EPOCH[5] - STEP[30]
# Generator_loss:1.8059
# L1_loss:0.1887
# Discriminator_loss:0.8502
#
# EPOCH[5] - STEP[40]
# Generator_loss:1.7366
# L1_loss:0.2113
# Discriminator_loss:0.4235
#
# EPOCH[5] - STEP[50]
# Generator_loss:2.1839
# L1_loss:0.2309
# Discriminator_loss:0.2406
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.4306
# L1_loss:0.1915
# Discriminator_loss:0.4769
#
# EPOCH[5] - STEP[70]
# Generator_loss:1.7840
# L1_loss:0.2132
# Discriminator_loss:0.7445
#
# EPOCH[5] - STEP[80]
# Generator_loss:1.3558
# L1_loss:0.1743
# Discriminator_loss:1.2403
#
# EPOCH[5] - STEP[90]
# Generator_loss:1.1429
# L1_loss:0.1848
# Discriminator_loss:0.7958
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.9827
# L1_loss:0.1922
# Discriminator_loss:0.6077
#
# EPOCH[5] - STEP[110]
# Generator_loss:2.6955
# L1_loss:0.1770
# Discriminator_loss:1.5848
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.4134
# L1_loss:0.2078
# Discriminator_loss:0.5519
#
# EPOCH[5] - STEP[130]
# Generator_loss:1.7770
# L1_loss:0.2011
# Discriminator_loss:0.4990
#
# EPOCH[5] - STEP[140]
# Generator_loss:2.9575
# L1_loss:0.1673
# Discriminator_loss:1.3800
#
# EPOCH[5] - STEP[150]
# Generator_loss:2.5557
# L1_loss:0.1758
# Discriminator_loss:0.8370
#
# EPOCH[5] - STEP[160]
# Generator_loss:2.9000
# L1_loss:0.2132
# Discriminator_loss:0.6458
#
# EPOCH[5] - STEP[170]
# Generator_loss:2.6830
# L1_loss:0.1609
# Discriminator_loss:1.5780
#
# EPOCH[5] - STEP[180]
# Generator_loss:1.4262
# L1_loss:0.1851
# Discriminator_loss:0.8254
#
# EPOCH[5] - STEP[190]
# Generator_loss:0.9878
# L1_loss:0.1872
# Discriminator_loss:0.7642
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.1791
# L1_loss:0.1518
# Discriminator_loss:0.9154
#
# EPOCH[5] - STEP[210]
# Generator_loss:1.7510
# L1_loss:0.1683
# Discriminator_loss:0.8799
#
# EPOCH[5] - STEP[220]
# Generator_loss:0.4601
# L1_loss:0.1775
# Discriminator_loss:1.3026
#
# EPOCH[5] - STEP[230]
# Generator_loss:1.7801
# L1_loss:0.1788
# Discriminator_loss:0.5569
#
# EPOCH[5] - STEP[240]
# Generator_loss:2.8710
# L1_loss:0.1868
# Discriminator_loss:1.8589
#
# EPOCH[5] - STEP[250]
# Generator_loss:2.6460
# L1_loss:0.2153
# Discriminator_loss:0.6155
#
# EPOCH[6] - STEP[10]
# Generator_loss:2.5208
# L1_loss:0.1856
# Discriminator_loss:1.1970
#
# EPOCH[6] - STEP[20]
# Generator_loss:0.5932
# L1_loss:0.2075
# Discriminator_loss:1.0442
#
# EPOCH[6] - STEP[30]
# Generator_loss:2.6116
# L1_loss:0.1925
# Discriminator_loss:1.0360
#
# EPOCH[6] - STEP[40]
# Generator_loss:1.6905
# L1_loss:0.1655
# Discriminator_loss:0.7025
#
# EPOCH[6] - STEP[50]
# Generator_loss:1.8211
# L1_loss:0.2065
# Discriminator_loss:0.8113
#
# EPOCH[6] - STEP[60]
# Generator_loss:0.5199
# L1_loss:0.1657
# Discriminator_loss:1.1719
#
# EPOCH[6] - STEP[70]
# Generator_loss:0.8097
# L1_loss:0.2306
# Discriminator_loss:0.8467
#
# EPOCH[6] - STEP[80]
# Generator_loss:2.2549
# L1_loss:0.2029
# Discriminator_loss:0.4348
#
# EPOCH[6] - STEP[90]
# Generator_loss:0.5856
# L1_loss:0.1942
# Discriminator_loss:1.1611
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.8586
# L1_loss:0.1867
# Discriminator_loss:0.4346
#
# EPOCH[6] - STEP[110]
# Generator_loss:0.6659
# L1_loss:0.1759
# Discriminator_loss:1.1057
#
# EPOCH[6] - STEP[120]
# Generator_loss:2.7015
# L1_loss:0.1677
# Discriminator_loss:0.7737
#
# EPOCH[6] - STEP[130]
# Generator_loss:1.7336
# L1_loss:0.2032
# Discriminator_loss:0.6012
#
# EPOCH[6] - STEP[140]
# Generator_loss:0.5414
# L1_loss:0.2280
# Discriminator_loss:1.1438
#
# EPOCH[6] - STEP[150]
# Generator_loss:1.4455
# L1_loss:0.1629
# Discriminator_loss:0.5596
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.7366
# L1_loss:0.2172
# Discriminator_loss:0.5160
#
# EPOCH[6] - STEP[170]
# Generator_loss:2.2533
# L1_loss:0.2135
# Discriminator_loss:0.6893
#
# EPOCH[6] - STEP[180]
# Generator_loss:0.8172
# L1_loss:0.1895
# Discriminator_loss:0.8825
#
# EPOCH[6] - STEP[190]
# Generator_loss:1.5408
# L1_loss:0.1603
# Discriminator_loss:1.4607
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.6105
# L1_loss:0.1844
# Discriminator_loss:0.4948
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.8910
# L1_loss:0.1736
# Discriminator_loss:1.2356
#
# EPOCH[6] - STEP[220]
# Generator_loss:0.7433
# L1_loss:0.2155
# Discriminator_loss:1.0145
#
# EPOCH[6] - STEP[230]
# Generator_loss:2.1137
# L1_loss:0.2198
# Discriminator_loss:0.3596
#
# EPOCH[6] - STEP[240]
# Generator_loss:2.6499
# L1_loss:0.1926
# Discriminator_loss:0.6202
#
# EPOCH[6] - STEP[250]
# Generator_loss:0.8660
# L1_loss:0.1881
# Discriminator_loss:0.7261
#
# EPOCH[7] - STEP[10]
# Generator_loss:1.0613
# L1_loss:0.2120
# Discriminator_loss:0.5694
#
# EPOCH[7] - STEP[20]
# Generator_loss:0.1981
# L1_loss:0.1705
# Discriminator_loss:2.0791
#
# EPOCH[7] - STEP[30]
# Generator_loss:1.8001
# L1_loss:0.1760
# Discriminator_loss:0.3780
#
# EPOCH[7] - STEP[40]
# Generator_loss:0.9349
# L1_loss:0.1895
# Discriminator_loss:0.7653
#
# EPOCH[7] - STEP[50]
# Generator_loss:0.7817
# L1_loss:0.1720
# Discriminator_loss:1.0441
#
# EPOCH[7] - STEP[60]
# Generator_loss:2.6760
# L1_loss:0.1744
# Discriminator_loss:0.5669
#
# EPOCH[7] - STEP[70]
# Generator_loss:3.0788
# L1_loss:0.1867
# Discriminator_loss:0.2808
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.6726
# L1_loss:0.1782
# Discriminator_loss:0.5698
#
# EPOCH[7] - STEP[90]
# Generator_loss:1.9576
# L1_loss:0.2230
# Discriminator_loss:0.5844
#
# EPOCH[7] - STEP[100]
# Generator_loss:2.0517
# L1_loss:0.1951
# Discriminator_loss:0.7882
#
# EPOCH[7] - STEP[110]
# Generator_loss:1.0422
# L1_loss:0.1605
# Discriminator_loss:0.9371
#
# EPOCH[7] - STEP[120]
# Generator_loss:3.1941
# L1_loss:0.2089
# Discriminator_loss:0.8205
#
# EPOCH[7] - STEP[130]
# Generator_loss:1.2278
# L1_loss:0.2081
# Discriminator_loss:0.7152
#
# EPOCH[7] - STEP[140]
# Generator_loss:0.4690
# L1_loss:0.2053
# Discriminator_loss:1.2076
#
# EPOCH[7] - STEP[150]
# Generator_loss:2.1888
# L1_loss:0.1748
# Discriminator_loss:0.5785
#
# EPOCH[7] - STEP[160]
# Generator_loss:2.5835
# L1_loss:0.1652
# Discriminator_loss:0.8337
#
# EPOCH[7] - STEP[170]
# Generator_loss:0.6727
# L1_loss:0.1667
# Discriminator_loss:1.0468
#
# EPOCH[7] - STEP[180]
# Generator_loss:0.7826
# L1_loss:0.1648
# Discriminator_loss:0.9314
#
# EPOCH[7] - STEP[190]
# Generator_loss:0.5242
# L1_loss:0.1841
# Discriminator_loss:1.4034
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.8147
# L1_loss:0.2275
# Discriminator_loss:0.5759
#
# EPOCH[7] - STEP[210]
# Generator_loss:2.7803
# L1_loss:0.1649
# Discriminator_loss:1.3556
#
# EPOCH[7] - STEP[220]
# Generator_loss:1.8315
# L1_loss:0.2017
# Discriminator_loss:0.2925
#
# EPOCH[7] - STEP[230]
# Generator_loss:1.3566
# L1_loss:0.1669
# Discriminator_loss:0.4808
#
# EPOCH[7] - STEP[240]
# Generator_loss:2.5751
# L1_loss:0.2733
# Discriminator_loss:0.6941
#
# EPOCH[7] - STEP[250]
# Generator_loss:1.9015
# L1_loss:0.1700
# Discriminator_loss:0.3169
#
# EPOCH[8] - STEP[10]
# Generator_loss:1.7424
# L1_loss:0.1894
# Discriminator_loss:0.6117
#
# EPOCH[8] - STEP[20]
# Generator_loss:2.7098
# L1_loss:0.2073
# Discriminator_loss:0.4337
#
# EPOCH[8] - STEP[30]
# Generator_loss:2.3795
# L1_loss:0.2458
# Discriminator_loss:0.4835
#
# EPOCH[8] - STEP[40]
# Generator_loss:1.0196
# L1_loss:0.1564
# Discriminator_loss:0.8254
#
# EPOCH[8] - STEP[50]
# Generator_loss:2.4267
# L1_loss:0.2387
# Discriminator_loss:0.2740
#
# EPOCH[8] - STEP[60]
# Generator_loss:2.9329
# L1_loss:0.1616
# Discriminator_loss:1.0471
#
# EPOCH[8] - STEP[70]
# Generator_loss:2.3092
# L1_loss:0.2027
# Discriminator_loss:0.6172
#
# EPOCH[8] - STEP[80]
# Generator_loss:2.4084
# L1_loss:0.2088
# Discriminator_loss:0.2510
#
# EPOCH[8] - STEP[90]
# Generator_loss:3.0674
# L1_loss:0.2055
# Discriminator_loss:0.2323
#
# EPOCH[8] - STEP[100]
# Generator_loss:1.9959
# L1_loss:0.2360
# Discriminator_loss:0.3221
#
# EPOCH[8] - STEP[110]
# Generator_loss:2.3469
# L1_loss:0.1707
# Discriminator_loss:1.1702
#
# EPOCH[8] - STEP[120]
# Generator_loss:2.3467
# L1_loss:0.1624
# Discriminator_loss:1.3088
#
# EPOCH[8] - STEP[130]
# Generator_loss:1.4552
# L1_loss:0.2020
# Discriminator_loss:0.6968
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.9250
# L1_loss:0.1791
# Discriminator_loss:0.3406
#
# EPOCH[8] - STEP[150]
# Generator_loss:0.5411
# L1_loss:0.2010
# Discriminator_loss:1.3030
#
# EPOCH[8] - STEP[160]
# Generator_loss:1.0772
# L1_loss:0.1435
# Discriminator_loss:0.7821
#
# EPOCH[8] - STEP[170]
# Generator_loss:1.8525
# L1_loss:0.1727
# Discriminator_loss:0.9555
#
# EPOCH[8] - STEP[180]
# Generator_loss:0.6384
# L1_loss:0.1648
# Discriminator_loss:1.2070
#
# EPOCH[8] - STEP[190]
# Generator_loss:2.3513
# L1_loss:0.1852
# Discriminator_loss:0.2702
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.9094
# L1_loss:0.2335
# Discriminator_loss:0.3264
#
# EPOCH[8] - STEP[210]
# Generator_loss:1.4008
# L1_loss:0.1959
# Discriminator_loss:0.4364
#
# EPOCH[8] - STEP[220]
# Generator_loss:0.5741
# L1_loss:0.1810
# Discriminator_loss:1.1708
#
# EPOCH[8] - STEP[230]
# Generator_loss:1.1244
# L1_loss:0.1613
# Discriminator_loss:0.9005
#
# EPOCH[8] - STEP[240]
# Generator_loss:2.2982
# L1_loss:0.1843
# Discriminator_loss:0.3298
#
# EPOCH[8] - STEP[250]
# Generator_loss:1.3906
# L1_loss:0.1717
# Discriminator_loss:0.5449
#
# EPOCH[9] - STEP[10]
# Generator_loss:0.5354
# L1_loss:0.2616
# Discriminator_loss:1.4584
#
# EPOCH[9] - STEP[20]
# Generator_loss:3.5959
# L1_loss:0.1742
# Discriminator_loss:0.7443
#
# EPOCH[9] - STEP[30]
# Generator_loss:4.0267
# L1_loss:0.2464
# Discriminator_loss:0.4056
#
# EPOCH[9] - STEP[40]
# Generator_loss:0.9943
# L1_loss:0.2167
# Discriminator_loss:0.7340
#
# EPOCH[9] - STEP[50]
# Generator_loss:2.4010
# L1_loss:0.1871
# Discriminator_loss:0.7844
#
# EPOCH[9] - STEP[60]
# Generator_loss:2.1271
# L1_loss:0.1820
# Discriminator_loss:0.4955
#
# EPOCH[9] - STEP[70]
# Generator_loss:0.7639
# L1_loss:0.1768
# Discriminator_loss:0.8797
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.5446
# L1_loss:0.1567
# Discriminator_loss:0.8555
#
# EPOCH[9] - STEP[90]
# Generator_loss:2.4910
# L1_loss:0.1948
# Discriminator_loss:0.2818
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.7337
# L1_loss:0.1815
# Discriminator_loss:2.5223
#
# EPOCH[9] - STEP[110]
# Generator_loss:2.1725
# L1_loss:0.2321
# Discriminator_loss:0.5722
#
# EPOCH[9] - STEP[120]
# Generator_loss:1.4050
# L1_loss:0.1761
# Discriminator_loss:0.6344
#
# EPOCH[9] - STEP[130]
# Generator_loss:1.7060
# L1_loss:0.2133
# Discriminator_loss:1.9454
#
# EPOCH[9] - STEP[140]
# Generator_loss:0.7782
# L1_loss:0.1767
# Discriminator_loss:0.7969
#
# EPOCH[9] - STEP[150]
# Generator_loss:2.2052
# L1_loss:0.1952
# Discriminator_loss:1.5401
#
# EPOCH[9] - STEP[160]
# Generator_loss:0.6387
# L1_loss:0.1923
# Discriminator_loss:0.9686
#
# EPOCH[9] - STEP[170]
# Generator_loss:0.7708
# L1_loss:0.2307
# Discriminator_loss:0.8006
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.5977
# L1_loss:0.1812
# Discriminator_loss:0.5121
#
# EPOCH[9] - STEP[190]
# Generator_loss:2.7538
# L1_loss:0.1671
# Discriminator_loss:0.7038
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.0768
# L1_loss:0.1503
# Discriminator_loss:1.6010
#
# EPOCH[9] - STEP[210]
# Generator_loss:2.8427
# L1_loss:0.2017
# Discriminator_loss:0.7995
#
# EPOCH[9] - STEP[220]
# Generator_loss:2.9176
# L1_loss:0.1866
# Discriminator_loss:0.2618
#
# EPOCH[9] - STEP[230]
# Generator_loss:0.8312
# L1_loss:0.1966
# Discriminator_loss:0.7206
#
# EPOCH[9] - STEP[240]
# Generator_loss:1.7033
# L1_loss:0.1722
# Discriminator_loss:0.6117
#
# EPOCH[9] - STEP[250]
# Generator_loss:1.3254
# L1_loss:0.1746
# Discriminator_loss:0.7035
#
# EPOCH[10] - STEP[10]
# Generator_loss:1.7283
# L1_loss:0.1729
# Discriminator_loss:0.5922
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.6859
# L1_loss:0.1662
# Discriminator_loss:0.3528
#
# EPOCH[10] - STEP[30]
# Generator_loss:1.4068
# L1_loss:0.1702
# Discriminator_loss:0.7587
#
# EPOCH[10] - STEP[40]
# Generator_loss:2.0968
# L1_loss:0.1656
# Discriminator_loss:1.4671
#
# EPOCH[10] - STEP[50]
# Generator_loss:0.5147
# L1_loss:0.1835
# Discriminator_loss:1.2687
#
# EPOCH[10] - STEP[60]
# Generator_loss:0.7971
# L1_loss:0.2044
# Discriminator_loss:1.2301
#
# EPOCH[10] - STEP[70]
# Generator_loss:2.4530
# L1_loss:0.1772
# Discriminator_loss:0.3013
#
# EPOCH[10] - STEP[80]
# Generator_loss:2.8547
# L1_loss:0.1738
# Discriminator_loss:0.4692
#
# EPOCH[10] - STEP[90]
# Generator_loss:1.4561
# L1_loss:0.1700
# Discriminator_loss:0.6078
#
# EPOCH[10] - STEP[100]
# Generator_loss:2.1326
# L1_loss:0.1673
# Discriminator_loss:0.8377
#
# EPOCH[10] - STEP[110]
# Generator_loss:1.6180
# L1_loss:0.2126
# Discriminator_loss:0.4061
#
# EPOCH[10] - STEP[120]
# Generator_loss:1.0489
# L1_loss:0.1811
# Discriminator_loss:1.2647
#
# EPOCH[10] - STEP[130]
# Generator_loss:1.2176
# L1_loss:0.1950
# Discriminator_loss:0.8004
#
# EPOCH[10] - STEP[140]
# Generator_loss:0.5451
# L1_loss:0.1972
# Discriminator_loss:1.3285
#
# EPOCH[10] - STEP[150]
# Generator_loss:2.0311
# L1_loss:0.1494
# Discriminator_loss:0.3889
#
# EPOCH[10] - STEP[160]
# Generator_loss:1.6392
# L1_loss:0.1537
# Discriminator_loss:0.6674
#
# EPOCH[10] - STEP[170]
# Generator_loss:3.2826
# L1_loss:0.1622
# Discriminator_loss:0.7151
#
# EPOCH[10] - STEP[180]
# Generator_loss:0.9311
# L1_loss:0.1904
# Discriminator_loss:1.2305
#
# EPOCH[10] - STEP[190]
# Generator_loss:1.8640
# L1_loss:0.1598
# Discriminator_loss:0.3928
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.4137
# L1_loss:0.1586
# Discriminator_loss:0.9874
#
# EPOCH[10] - STEP[210]
# Generator_loss:0.7555
# L1_loss:0.1766
# Discriminator_loss:0.9335
#
# EPOCH[10] - STEP[220]
# Generator_loss:3.4426
# L1_loss:0.1556
# Discriminator_loss:1.0902
#
# EPOCH[10] - STEP[230]
# Generator_loss:1.2629
# L1_loss:0.1684
# Discriminator_loss:0.6699
#
# EPOCH[10] - STEP[240]
# Generator_loss:1.4880
# L1_loss:0.1478
# Discriminator_loss:0.9069
#
# EPOCH[10] - STEP[250]
# Generator_loss:0.5265
# L1_loss:0.1766
# Discriminator_loss:1.2805
#
# EPOCH[11] - STEP[10]
# Generator_loss:1.4170
# L1_loss:0.1743
# Discriminator_loss:1.0544
#
# EPOCH[11] - STEP[20]
# Generator_loss:2.3289
# L1_loss:0.2002
# Discriminator_loss:0.2959
#
# EPOCH[11] - STEP[30]
# Generator_loss:2.2350
# L1_loss:0.1971
# Discriminator_loss:0.4799
#
# EPOCH[11] - STEP[40]
# Generator_loss:2.8866
# L1_loss:0.2112
# Discriminator_loss:0.3510
#
# EPOCH[11] - STEP[50]
# Generator_loss:2.2756
# L1_loss:0.2069
# Discriminator_loss:0.4006
#
# EPOCH[11] - STEP[60]
# Generator_loss:1.7133
# L1_loss:0.1677
# Discriminator_loss:0.5754
#
# EPOCH[11] - STEP[70]
# Generator_loss:0.4564
# L1_loss:0.1632
# Discriminator_loss:1.4072
#
# EPOCH[11] - STEP[80]
# Generator_loss:1.9855
# L1_loss:0.1844
# Discriminator_loss:0.5667
#
# EPOCH[11] - STEP[90]
# Generator_loss:3.6443
# L1_loss:0.1592
# Discriminator_loss:0.7095
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.1419
# L1_loss:0.1910
# Discriminator_loss:0.4259
#
# EPOCH[11] - STEP[110]
# Generator_loss:1.9205
# L1_loss:0.1535
# Discriminator_loss:0.3202
#
# EPOCH[11] - STEP[120]
# Generator_loss:1.6344
# L1_loss:0.1775
# Discriminator_loss:0.3453
#
# EPOCH[11] - STEP[130]
# Generator_loss:2.5010
# L1_loss:0.1416
# Discriminator_loss:1.4248
#
# EPOCH[11] - STEP[140]
# Generator_loss:2.6807
# L1_loss:0.1670
# Discriminator_loss:1.0542
#
# EPOCH[11] - STEP[150]
# Generator_loss:2.0489
# L1_loss:0.1791
# Discriminator_loss:0.2589
#
# EPOCH[11] - STEP[160]
# Generator_loss:1.7602
# L1_loss:0.1944
# Discriminator_loss:0.3526
#
# EPOCH[11] - STEP[170]
# Generator_loss:1.9980
# L1_loss:0.1904
# Discriminator_loss:1.2181
#
# EPOCH[11] - STEP[180]
# Generator_loss:1.5496
# L1_loss:0.2633
# Discriminator_loss:0.4228
#
# EPOCH[11] - STEP[190]
# Generator_loss:3.4306
# L1_loss:0.1959
# Discriminator_loss:0.2250
#
# EPOCH[11] - STEP[200]
# Generator_loss:3.1411
# L1_loss:0.1684
# Discriminator_loss:1.0717
#
# EPOCH[11] - STEP[210]
# Generator_loss:2.5287
# L1_loss:0.1427
# Discriminator_loss:1.2788
#
# EPOCH[11] - STEP[220]
# Generator_loss:0.6948
# L1_loss:0.2029
# Discriminator_loss:1.0208
#
# EPOCH[11] - STEP[230]
# Generator_loss:1.3920
# L1_loss:0.1886
# Discriminator_loss:0.4086
#
# EPOCH[11] - STEP[240]
# Generator_loss:1.2079
# L1_loss:0.1420
# Discriminator_loss:1.2026
#
# EPOCH[11] - STEP[250]
# Generator_loss:1.5875
# L1_loss:0.1806
# Discriminator_loss:0.4453
#
# EPOCH[12] - STEP[10]
# Generator_loss:1.5625
# L1_loss:0.1689
# Discriminator_loss:0.7155
#
# EPOCH[12] - STEP[20]
# Generator_loss:2.2131
# L1_loss:0.1600
# Discriminator_loss:0.5306
#
# EPOCH[12] - STEP[30]
# Generator_loss:1.9905
# L1_loss:0.1738
# Discriminator_loss:0.8081
#
# EPOCH[12] - STEP[40]
# Generator_loss:1.1799
# L1_loss:0.1879
# Discriminator_loss:0.6764
#
# EPOCH[12] - STEP[50]
# Generator_loss:2.4043
# L1_loss:0.1729
# Discriminator_loss:0.7564
#
# EPOCH[12] - STEP[60]
# Generator_loss:2.4230
# L1_loss:0.2326
# Discriminator_loss:0.2423
#
# EPOCH[12] - STEP[70]
# Generator_loss:1.0053
# L1_loss:0.1938
# Discriminator_loss:0.7089
#
# EPOCH[12] - STEP[80]
# Generator_loss:0.9845
# L1_loss:0.1394
# Discriminator_loss:1.0407
#
# EPOCH[12] - STEP[90]
# Generator_loss:1.1557
# L1_loss:0.1947
# Discriminator_loss:0.7436
#
# EPOCH[12] - STEP[100]
# Generator_loss:2.5628
# L1_loss:0.2164
# Discriminator_loss:0.3046
#
# EPOCH[12] - STEP[110]
# Generator_loss:2.3975
# L1_loss:0.1764
# Discriminator_loss:0.5122
#
# EPOCH[12] - STEP[120]
# Generator_loss:1.7531
# L1_loss:0.1772
# Discriminator_loss:0.2619
#
# EPOCH[12] - STEP[130]
# Generator_loss:1.6562
# L1_loss:0.1575
# Discriminator_loss:1.3161
#
# EPOCH[12] - STEP[140]
# Generator_loss:2.1388
# L1_loss:0.1929
# Discriminator_loss:0.2432
#
# EPOCH[12] - STEP[150]
# Generator_loss:3.1134
# L1_loss:0.1878
# Discriminator_loss:0.5911
#
# EPOCH[12] - STEP[160]
# Generator_loss:0.5527
# L1_loss:0.1822
# Discriminator_loss:1.1531
#
# EPOCH[12] - STEP[170]
# Generator_loss:1.3830
# L1_loss:0.1716
# Discriminator_loss:0.5413
#
# EPOCH[12] - STEP[180]
# Generator_loss:1.3053
# L1_loss:0.1669
# Discriminator_loss:0.8987
#
# EPOCH[12] - STEP[190]
# Generator_loss:1.3458
# L1_loss:0.1703
# Discriminator_loss:0.5979
#
# EPOCH[12] - STEP[200]
# Generator_loss:2.8617
# L1_loss:0.1551
# Discriminator_loss:0.3509
#
# EPOCH[12] - STEP[210]
# Generator_loss:1.6765
# L1_loss:0.1885
# Discriminator_loss:0.5182
#
# EPOCH[12] - STEP[220]
# Generator_loss:3.1067
# L1_loss:0.1718
# Discriminator_loss:0.2857
#
# EPOCH[12] - STEP[230]
# Generator_loss:1.1611
# L1_loss:0.1687
# Discriminator_loss:1.3930
#
# EPOCH[12] - STEP[240]
# Generator_loss:2.0019
# L1_loss:0.1633
# Discriminator_loss:0.4804
#
# EPOCH[12] - STEP[250]
# Generator_loss:2.0980
# L1_loss:0.1551
# Discriminator_loss:0.8826
#
# EPOCH[13] - STEP[10]
# Generator_loss:3.2891
# L1_loss:0.1593
# Discriminator_loss:0.2147
#
# EPOCH[13] - STEP[20]
# Generator_loss:1.5909
# L1_loss:0.1829
# Discriminator_loss:0.5050
#
# EPOCH[13] - STEP[30]
# Generator_loss:1.9150
# L1_loss:0.1747
# Discriminator_loss:0.8549
#
# EPOCH[13] - STEP[40]
# Generator_loss:2.5282
# L1_loss:0.1653
# Discriminator_loss:0.3791
#
# EPOCH[13] - STEP[50]
# Generator_loss:0.4885
# L1_loss:0.2060
# Discriminator_loss:1.2293
#
# EPOCH[13] - STEP[60]
# Generator_loss:1.7539
# L1_loss:0.1737
# Discriminator_loss:0.8051
#
# EPOCH[13] - STEP[70]
# Generator_loss:0.8743
# L1_loss:0.1746
# Discriminator_loss:0.7175
#
# EPOCH[13] - STEP[80]
# Generator_loss:2.0814
# L1_loss:0.1590
# Discriminator_loss:0.7892
#
# EPOCH[13] - STEP[90]
# Generator_loss:0.6762
# L1_loss:0.2106
# Discriminator_loss:1.0639
#
# EPOCH[13] - STEP[100]
# Generator_loss:2.3139
# L1_loss:0.1711
# Discriminator_loss:0.3536
#
# EPOCH[13] - STEP[110]
# Generator_loss:1.8214
# L1_loss:0.1525
# Discriminator_loss:0.7017
#
# EPOCH[13] - STEP[120]
# Generator_loss:0.5970
# L1_loss:0.1456
# Discriminator_loss:1.1253
#
# EPOCH[13] - STEP[130]
# Generator_loss:1.3430
# L1_loss:0.1695
# Discriminator_loss:0.4517
#
# EPOCH[13] - STEP[140]
# Generator_loss:2.5246
# L1_loss:0.1545
# Discriminator_loss:1.2160
#
# EPOCH[13] - STEP[150]
# Generator_loss:1.1236
# L1_loss:0.1899
# Discriminator_loss:0.6152
#
# EPOCH[13] - STEP[160]
# Generator_loss:2.4920
# L1_loss:0.1628
# Discriminator_loss:0.1896
#
# EPOCH[13] - STEP[170]
# Generator_loss:1.4771
# L1_loss:0.1454
# Discriminator_loss:0.5955
#
# EPOCH[13] - STEP[180]
# Generator_loss:0.6332
# L1_loss:0.1466
# Discriminator_loss:1.0684
#
# EPOCH[13] - STEP[190]
# Generator_loss:2.1294
# L1_loss:0.1664
# Discriminator_loss:1.0433
#
# EPOCH[13] - STEP[200]
# Generator_loss:0.5027
# L1_loss:0.1872
# Discriminator_loss:1.1225
#
# EPOCH[13] - STEP[210]
# Generator_loss:1.1313
# L1_loss:0.1306
# Discriminator_loss:0.6612
#
# EPOCH[13] - STEP[220]
# Generator_loss:2.6664
# L1_loss:0.1911
# Discriminator_loss:0.2360
#
# EPOCH[13] - STEP[230]
# Generator_loss:3.7488
# L1_loss:0.2246
# Discriminator_loss:0.5330
#
# EPOCH[13] - STEP[240]
# Generator_loss:2.1050
# L1_loss:0.1838
# Discriminator_loss:0.5191
#
# EPOCH[13] - STEP[250]
# ...
# L1_loss:0.1188
# Discriminator_loss:1.1930
#
# EPOCH[96] - STEP[190]
# Generator_loss:5.3381
# L1_loss:0.1705
# Discriminator_loss:0.0133
#
# EPOCH[96] - STEP[200]
# Generator_loss:7.0825
# L1_loss:0.1359
# Discriminator_loss:0.4455
#
# EPOCH[96] - STEP[210]
# Generator_loss:0.9828
# L1_loss:0.1096
# Discriminator_loss:0.8191
#
# EPOCH[96] - STEP[220]
# Generator_loss:4.3736
# L1_loss:0.1457
# Discriminator_loss:0.3963
#
# EPOCH[96] - STEP[230]
# Generator_loss:5.2957
# L1_loss:0.1419
# Discriminator_loss:0.0562
#
# EPOCH[96] - STEP[240]
# Generator_loss:2.2564
# L1_loss:0.1468
# Discriminator_loss:0.2704
#
# EPOCH[96] - STEP[250]
# Generator_loss:3.3231
# L1_loss:0.1530
# Discriminator_loss:0.4667
#
# EPOCH[97] - STEP[10]
# Generator_loss:5.5507
# L1_loss:0.1485
# Discriminator_loss:0.0343
#
# EPOCH[97] - STEP[20]
# Generator_loss:3.1522
# L1_loss:0.1141
# Discriminator_loss:0.3283
#
# EPOCH[97] - STEP[30]
# Generator_loss:3.5042
# L1_loss:0.1584
# Discriminator_loss:0.2937
#
# EPOCH[97] - STEP[40]
# Generator_loss:0.1944
# L1_loss:0.1668
# Discriminator_loss:2.7917
#
# EPOCH[97] - STEP[50]
# Generator_loss:1.0542
# L1_loss:0.1604
# Discriminator_loss:0.7796
#
# EPOCH[97] - STEP[60]
# Generator_loss:2.3988
# L1_loss:0.0969
# Discriminator_loss:0.2907
#
# EPOCH[97] - STEP[70]
# Generator_loss:3.8219
# L1_loss:0.1325
# Discriminator_loss:0.1200
#
# EPOCH[97] - STEP[80]
# Generator_loss:2.0489
# L1_loss:0.1186
# Discriminator_loss:0.2713
#
# EPOCH[97] - STEP[90]
# Generator_loss:3.9692
# L1_loss:0.1265
# Discriminator_loss:1.0466
#
# EPOCH[97] - STEP[100]
# Generator_loss:2.5661
# L1_loss:0.0989
# Discriminator_loss:0.4977
#
# EPOCH[97] - STEP[110]
# Generator_loss:3.2759
# L1_loss:0.2010
# Discriminator_loss:0.1014
#
# EPOCH[97] - STEP[120]
# Generator_loss:3.2411
# L1_loss:0.1549
# Discriminator_loss:0.2321
#
# EPOCH[97] - STEP[130]
# Generator_loss:3.7643
# L1_loss:0.1319
# Discriminator_loss:0.1481
#
# EPOCH[97] - STEP[140]
# Generator_loss:3.5145
# L1_loss:0.1541
# Discriminator_loss:0.0785
#
# EPOCH[97] - STEP[150]
# Generator_loss:1.9077
# L1_loss:0.1374
# Discriminator_loss:0.3060
#
# EPOCH[97] - STEP[160]
# Generator_loss:4.0574
# L1_loss:0.1035
# Discriminator_loss:1.4447
#
# EPOCH[97] - STEP[170]
# Generator_loss:2.9662
# L1_loss:0.1174
# Discriminator_loss:0.1396
#
# EPOCH[97] - STEP[180]
# Generator_loss:6.6207
# L1_loss:0.1173
# Discriminator_loss:0.1023
#
# EPOCH[97] - STEP[190]
# Generator_loss:5.3301
# L1_loss:0.1265
# Discriminator_loss:0.1271
#
# EPOCH[97] - STEP[200]
# Generator_loss:2.5250
# L1_loss:0.1316
# Discriminator_loss:0.2477
#
# EPOCH[97] - STEP[210]
# Generator_loss:3.1365
# L1_loss:0.1343
# Discriminator_loss:1.2935
#
# EPOCH[97] - STEP[220]
# Generator_loss:2.9942
# L1_loss:0.1227
# Discriminator_loss:0.6068
#
# EPOCH[97] - STEP[230]
# Generator_loss:4.3613
# L1_loss:0.1174
# Discriminator_loss:0.1066
#
# EPOCH[97] - STEP[240]
# Generator_loss:5.1096
# L1_loss:0.1361
# Discriminator_loss:0.1015
#
# EPOCH[97] - STEP[250]
# Generator_loss:2.8120
# L1_loss:0.1009
# Discriminator_loss:0.2236
#
# EPOCH[98] - STEP[10]
# Generator_loss:1.9262
# L1_loss:0.1439
# Discriminator_loss:0.3562
#
# EPOCH[98] - STEP[20]
# Generator_loss:3.0489
# L1_loss:0.1262
# Discriminator_loss:0.1708
#
# EPOCH[98] - STEP[30]
# Generator_loss:6.2862
# L1_loss:0.1537
# Discriminator_loss:0.6674
#
# EPOCH[98] - STEP[40]
# Generator_loss:4.9427
# L1_loss:0.1643
# Discriminator_loss:0.1174
#
# EPOCH[98] - STEP[50]
# Generator_loss:3.8576
# L1_loss:0.1189
# Discriminator_loss:0.4574
#
# EPOCH[98] - STEP[60]
# Generator_loss:2.7966
# L1_loss:0.1081
# Discriminator_loss:0.1835
#
# EPOCH[98] - STEP[70]
# Generator_loss:3.6951
# L1_loss:0.1084
# Discriminator_loss:0.0961
#
# EPOCH[98] - STEP[80]
# Generator_loss:2.5161
# L1_loss:0.1192
# Discriminator_loss:0.1868
#
# EPOCH[98] - STEP[90]
# Generator_loss:1.2667
# L1_loss:0.1099
# Discriminator_loss:0.5162
#
# EPOCH[98] - STEP[100]
# Generator_loss:5.9856
# L1_loss:0.1317
# Discriminator_loss:0.3673
#
# EPOCH[98] - STEP[110]
# Generator_loss:2.8266
# L1_loss:0.1213
# Discriminator_loss:0.2987
#
# EPOCH[98] - STEP[120]
# Generator_loss:4.8277
# L1_loss:0.1278
# Discriminator_loss:0.0791
#
# EPOCH[98] - STEP[130]
# Generator_loss:2.4552
# L1_loss:0.1136
# Discriminator_loss:0.6380
#
# EPOCH[98] - STEP[140]
# Generator_loss:6.1264
# L1_loss:0.1003
# Discriminator_loss:2.2332
#
# EPOCH[98] - STEP[150]
# Generator_loss:3.3479
# L1_loss:0.1484
# Discriminator_loss:0.5102
#
# EPOCH[98] - STEP[160]
# Generator_loss:1.8635
# L1_loss:0.1646
# Discriminator_loss:0.4253
#
# EPOCH[98] - STEP[170]
# Generator_loss:3.8316
# L1_loss:0.1439
# Discriminator_loss:0.3662
#
# EPOCH[98] - STEP[180]
# Generator_loss:5.0412
# L1_loss:0.1449
# Discriminator_loss:2.0896
#
# EPOCH[98] - STEP[190]
# Generator_loss:3.9321
# L1_loss:0.1183
# Discriminator_loss:0.1550
#
# EPOCH[98] - STEP[200]
# Generator_loss:4.4734
# L1_loss:0.1641
# Discriminator_loss:0.0462
#
# EPOCH[98] - STEP[210]
# Generator_loss:1.4091
# L1_loss:0.1310
# Discriminator_loss:0.4831
#
# EPOCH[98] - STEP[220]
# Generator_loss:0.8223
# L1_loss:0.1393
# Discriminator_loss:1.2111
#
# EPOCH[98] - STEP[230]
# Generator_loss:1.9025
# L1_loss:0.1624
# Discriminator_loss:0.3057
#
# EPOCH[98] - STEP[240]
# Generator_loss:5.8801
# L1_loss:0.1231
# Discriminator_loss:0.1586
#
# EPOCH[98] - STEP[250]
# Generator_loss:2.3247
# L1_loss:0.1470
# Discriminator_loss:0.2607
#
# EPOCH[99] - STEP[10]
# Generator_loss:5.2912
# L1_loss:0.1289
# Discriminator_loss:0.0535
#
# EPOCH[99] - STEP[20]
# Generator_loss:3.5467
# L1_loss:0.1437
# Discriminator_loss:0.1834
#
# EPOCH[99] - STEP[30]
# Generator_loss:2.2114
# L1_loss:0.1341
# Discriminator_loss:0.3082
#
# EPOCH[99] - STEP[40]
# Generator_loss:4.8062
# L1_loss:0.1426
# Discriminator_loss:0.2438
#
# EPOCH[99] - STEP[50]
# Generator_loss:2.9483
# L1_loss:0.1086
# Discriminator_loss:0.2185
#
# EPOCH[99] - STEP[60]
# Generator_loss:2.5161
# L1_loss:0.1026
# Discriminator_loss:0.9321
#
# EPOCH[99] - STEP[70]
# Generator_loss:2.2937
# L1_loss:0.1303
# Discriminator_loss:0.2074
#
# EPOCH[99] - STEP[80]
# Generator_loss:2.8489
# L1_loss:0.1493
# Discriminator_loss:0.1295
#
# EPOCH[99] - STEP[90]
# Generator_loss:3.8996
# L1_loss:0.1127
# Discriminator_loss:0.2681
#
# EPOCH[99] - STEP[100]
# Generator_loss:5.1097
# L1_loss:0.1054
# Discriminator_loss:1.3613
#
# EPOCH[99] - STEP[110]
# Generator_loss:1.8457
# L1_loss:0.1117
# Discriminator_loss:0.6700
#
# EPOCH[99] - STEP[120]
# Generator_loss:2.9710
# L1_loss:0.1383
# Discriminator_loss:0.1852
#
# EPOCH[99] - STEP[130]
# Generator_loss:2.3861
# L1_loss:0.1355
# Discriminator_loss:0.2134
#
# EPOCH[99] - STEP[140]
# Generator_loss:1.4690
# L1_loss:0.1297
# Discriminator_loss:0.7933
#
# EPOCH[99] - STEP[150]
# Generator_loss:3.3307
# L1_loss:0.1064
# Discriminator_loss:0.9209
#
# EPOCH[99] - STEP[160]
# Generator_loss:1.1776
# L1_loss:0.1088
# Discriminator_loss:0.7155
#
# EPOCH[99] - STEP[170]
# Generator_loss:4.0630
# L1_loss:0.1116
# Discriminator_loss:0.8090
#
# EPOCH[99] - STEP[180]
# Generator_loss:2.0344
# L1_loss:0.1036
# Discriminator_loss:0.7951
#
# EPOCH[99] - STEP[190]
# Generator_loss:3.5627
# L1_loss:0.1227
# Discriminator_loss:0.0908
#
# EPOCH[99] - STEP[200]
# Generator_loss:3.9588
# L1_loss:0.1426
# Discriminator_loss:0.1804
#
# EPOCH[99] - STEP[210]
# Generator_loss:6.3749
# L1_loss:0.1215
# Discriminator_loss:1.6492
#
# EPOCH[99] - STEP[220]
# Generator_loss:2.7320
# L1_loss:0.0958
# Discriminator_loss:1.2158
#
# EPOCH[99] - STEP[230]
# Generator_loss:4.7092
# L1_loss:0.1488
# Discriminator_loss:0.4944
#
# EPOCH[99] - STEP[240]
# Generator_loss:4.5792
# L1_loss:0.1377
# Discriminator_loss:0.0517
#
# EPOCH[99] - STEP[250]
# Generator_loss:5.3486
# L1_loss:0.1195
# Discriminator_loss:0.6024
#
# EPOCH[100] - STEP[10]
# Generator_loss:2.9696
# L1_loss:0.1181
# Discriminator_loss:0.1587
#
# EPOCH[100] - STEP[20]
# Generator_loss:3.5365
# L1_loss:0.1199
# Discriminator_loss:0.2000
#
# EPOCH[100] - STEP[30]
# Generator_loss:3.7708
# L1_loss:0.1193
# Discriminator_loss:0.3622
#
# EPOCH[100] - STEP[40]
# Generator_loss:2.3843
# L1_loss:0.1252
# Discriminator_loss:0.1820
#
# EPOCH[100] - STEP[50]
# Generator_loss:2.3246
# L1_loss:0.1408
# Discriminator_loss:0.2626
#
# EPOCH[100] - STEP[60]
# Generator_loss:2.6663
# L1_loss:0.1253
# Discriminator_loss:0.1927
#
# EPOCH[100] - STEP[70]
# Generator_loss:3.3515
# L1_loss:0.1181
# Discriminator_loss:0.0912
#
# EPOCH[100] - STEP[80]
# Generator_loss:2.1476
# L1_loss:0.1685
# Discriminator_loss:0.2209
#
# EPOCH[100] - STEP[90]
# Generator_loss:3.1252
# L1_loss:0.1371
# Discriminator_loss:0.0823
#
# EPOCH[100] - STEP[100]
# Generator_loss:4.0942
# L1_loss:0.1278
# Discriminator_loss:0.1283
#
# EPOCH[100] - STEP[110]
# Generator_loss:6.1376
# L1_loss:0.1112
# Discriminator_loss:0.6511
#
# EPOCH[100] - STEP[120]
# Generator_loss:3.9506
# L1_loss:0.1710
# Discriminator_loss:0.0580
#
# EPOCH[100] - STEP[130]
# Generator_loss:2.7574
# L1_loss:0.1150
# Discriminator_loss:0.4028
#
# EPOCH[100] - STEP[140]
# Generator_loss:4.2782
# L1_loss:0.1256
# Discriminator_loss:0.1710
#
# EPOCH[100] - STEP[150]
# Generator_loss:6.7388
# L1_loss:0.1355
# Discriminator_loss:0.0477
#
# EPOCH[100] - STEP[160]
# Generator_loss:2.3921
# L1_loss:0.1473
# Discriminator_loss:0.2357
#
# EPOCH[100] - STEP[170]
# Generator_loss:5.1376
# L1_loss:0.1327
# Discriminator_loss:0.2388
#
# EPOCH[100] - STEP[180]
# Generator_loss:4.4704
# L1_loss:0.1317
# Discriminator_loss:0.5812
#
# EPOCH[100] - STEP[190]
# Generator_loss:2.4213
# L1_loss:0.1271
# Discriminator_loss:0.3444
#
# EPOCH[100] - STEP[200]
# Generator_loss:4.6895
# L1_loss:0.1088
# Discriminator_loss:0.4327
#
# EPOCH[100] - STEP[210]
# Generator_loss:2.3952
# L1_loss:0.1065
# Discriminator_loss:0.9525
#
# EPOCH[100] - STEP[220]
# Generator_loss:3.3285
# L1_loss:0.1082
# Discriminator_loss:0.1062
#
# EPOCH[100] - STEP[230]
# Generator_loss:3.7590
# L1_loss:0.1026
# Discriminator_loss:0.3109
#
# EPOCH[100] - STEP[240]
# Generator_loss:2.7686
# L1_loss:0.1299
# Discriminator_loss:0.3563
#
# EPOCH[100] - STEP[250]
# Generator_loss:6.9009
# L1_loss:0.1596
# Discriminator_loss:0.2649

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# ### epoch = 50
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### epoch = 100
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 프로젝트 결과 및 회고
# - 이번 프로젝트는 augmentation 방법과 U Net Generator, discriminator를 활용하여 도로 이미지를 만들어보는 프로젝트 입니다.
# - 이번 프로젝트에서는 학습할 때 epoch을 50과 100으로 진행해 보기로 설계하고 진행하였습니다. 우선 50 epoch을 수행했을 때와 100epoch을 수행했을 때 결과 이미지를 살펴보면 육안으로는 거의 차이가 없는 것을 확인할 수 있었습니다. 이를 통해 일정 epoch 이상을 수행할 경우 결과 이미지에 큰 차이점이 없는 것을 확인할 수 있었습니다. 아쉬운 점은 코드 수행시간이 오래 걸렸음에도 불구하고 예상보다 결과가 세밀하게 나오지는 않아 이를 보완하고 개선할 수 있는 방법에 대한 학습이 필요하다는 생각이 들었습니다.
